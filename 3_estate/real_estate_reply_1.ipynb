# %% [markdown]
# #### Миша, привет!
#
# Меня зовут Максим Попов, и я буду проверять твой проект. Давай будем общаться на «ты». Но если тебе комфортнее на «вы», обязательно сообщи мне об этом.
# По ходу тетрадки ты найдешь комментарии к проекту, они будут в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Постарайся учесть эти комментарии для дальнейших проектов.
#
# ---
#
# Я буду отмечать комментарии цветом и примечанием. В конце заголовка комментария будет указан номер итерации проверки. Пожалуйста, не удаляй и не правь мои комментарии
#
# Критично - требует исправления, влияет на удачное выполнение проекта
#
# Рекомендация - комментарий является рекомендацией или советом. Mожешь учесть их при выполнении будущих заданий. На твое усмотрение
#
# Отлично - Так отмечены удачные решения и подходы, на которые стоит опираться в будущих проектах
#
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий от ревьюера
# Критично
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера
# Рекомендация
#
# Такой комментарий является рекомендацией или советом. Mожешь учесть их при выполнении будущих заданий. На твое усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера
# Отлично
#
# Так отмечены удачные решения и подходы, на которые стоит опираться в будущих проектах
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Миша, у тебя отличная работа, но следущие моменты нужно переделать:
#
# 1. <s>Прокомментировать пропуски</s>
# 2. <s>Выделение из даты дня недели</s>
# 3. <s>Чистка выбивающихся значений</s>
# 4. <s>Анализ факторов, влияющих на цену</s>
# 5. <s>Добавить анализ по другому этажу в центр СПБ</s>
#
# Подробные комментарии по ходу работы
#
# Желтые комментарии-рекомендации на твое усмотрение.
#
# Если есть вопросы ко мне, можешь оставить их в отдельном комментарии
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Миша,-привет!" data-toc-modified-id="Миша,-привет!-0.0.0.1">Миша, привет!</a></span></li></ul></li><li><span><a href="#Комментарий-от-ревьюера" data-toc-modified-id="Комментарий-от-ревьюера-0.0.1">Комментарий от ревьюера</a></span></li><li><span><a href="#Комментарий-от-ревьюера" data-toc-modified-id="Комментарий-от-ревьюера-0.0.2">Комментарий от ревьюера</a></span></li><li><span><a href="#Комментарий-от-ревьюера" data-toc-modified-id="Комментарий-от-ревьюера-0.0.3">Комментарий от ревьюера</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-0.0.4">Комментарий от ревьюера v_1</a></span></li></ul></li></ul></li><li><span><a href="#Исследование-объявлений-о-продаже-квартир" data-toc-modified-id="Исследование-объявлений-о-продаже-квартир-1">Исследование объявлений о продаже квартир</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.0.1">Комментарий от ревьюера v_1</a></span></li></ul></li><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1.1">Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.1.1">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1.2">Вывод</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.1.3">Комментарий от ревьюера v_1</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.2">Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.2.1">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.2.2">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.2.3">Вывод</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.2.4">Комментарий от ревьюера v_1</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-1.3">Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.3.1">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.3.2">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.3.3">Вывод</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.3.4">Комментарий от ревьюера v_1</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-1.4">Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.1">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.2">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.3">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.4">Комментарий от ревьюера v_1</a></span><ul class="toc-item"><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?" data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-1.4.4.1">Какие факторы больше всего влияют на стоимость квартиры?</a></span></li></ul></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.5">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.6">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.7">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.8">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.9">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Квартиры-в-центре" data-toc-modified-id="Квартиры-в-центре-1.4.10">Квартиры в центре</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.11">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.12">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.13">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.14">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.4.15">Вывод</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-1.5">Общий вывод</a></span><ul class="toc-item"><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.5.1">Комментарий от ревьюера v_1</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-1.6">Чек-лист готовности проекта</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
#
# Молодец, что в начале проекте знакомишь с ним, так работа приобретает структуру и лучше воспринимается.
# </div>

# %% [markdown]
# ## Изучение данных из файла

# %%
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10, 6)

import seaborn as sns

sns.set_context('notebook', font_scale=1.5)
sns.set_style('darkgrid', rc={'ytick.left':True, 'ytick.direction':'in',
                              'xtick.bottom':True, 'xtick.direction':'in'})

# Обновление требуется для доступа к sns.histplot()
# %pip install seaborn==0.11.2

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
#
# Отлично, библиотеки и параметры импортированы в начале тетрадки, в отдельной ячейке.
# </div>

# %% [markdown]
# - `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м)
# - `balcony` — число балконов
# - `ceiling_height` — высота потолков (м)
# - `cityCenters_nearest` — расстояние до центра города (м)
# - `days_exposition` — сколько дней было размещено объявление (от публикации до снятия)
# - `first_day_exposition` — дата публикации
# - `floor` — этаж
# - `floors_total` — всего этажей в доме
# - `is_apartment` — апартаменты (булев тип)
# - `kitchen_area` — площадь кухни в квадратных метрах (м²)
# - `last_price` — цена на момент снятия с публикации
# - `living_area` — жилая площадь в квадратных метрах (м²)
# - `locality_name` — название населённого пункта
# - `open_plan` — свободная планировка (булев тип)
# - `parks_around3000` — число парков в радиусе 3 км
# - `parks_nearest` — расстояние до ближайшего парка (м)
# - `ponds_around3000` — число водоёмов в радиусе 3 км
# - `ponds_nearest` — расстояние до ближайшего водоёма (м)
# - `rooms` — число комнат
# - `studio` — квартира-студия (булев тип)
# - `total_area` — площадь квартиры в квадратных метрах (м²)
# - `total_images` — число фотографий квартиры в объявлении

# %%
# init_df - датафрейм в исходном виде
init_df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# df - датафрейм для преобразования
df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
df.shape
# Out:
# (23699, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %%
df.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# - Всего в датафрейме 23699 строк и 22 столбца
# - Во многих стобцах присутствуют пропущенные значения

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
#
# Данные загружены, приступаем к предобработке
#
# Также рекомендую использовать describe для первичного взгляда на количественные переменные
#
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
# Рекомендация
#
# В начале шага следует написать перечень действий, который планируешь выполнить. Так ты ничего не упустишь и добавишь проекту структуры
# </div>

# %% [markdown]
# ### Ответ от студента v_1
# <blockquote>
#     Усвоил, обращу внимание в дальнейших проектах
# </blockquote>

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
df.isna().sum().sort_values()
# Out:
# total_images                0
# open_plan                   0
# floor                       0
# rooms                       0
# studio                      0
# total_area                  0
# last_price                  0
# first_day_exposition        0
# locality_name              49
# floors_total               86
# living_area              1903
# kitchen_area             2278
# days_exposition          3181
# ponds_around3000         5518
# parks_around3000         5518
# cityCenters_nearest      5519
# airports_nearest         5542
# ceiling_height           9195
# balcony                 11519
# ponds_nearest           14589
# parks_nearest           15620
# is_apartment            20924
# dtype: int64

# %% [markdown]
# Пропущенные значения есть более чем в половине колонок.
#
# 1. Допустим, что в квартирах с пропусками в колонке `balcony` балконов нет. Предположу, с `ponds_around3000` и `parks_around3000` аналогичная ситуация.
#
# 2. Нулевые значения в колонке `rooms` заменю на единицы, потому что не могу представить квартиру без комнат.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
# Рекомендация
#
# Не пиши сплошным текстом, структурируй свои мысли:
#
# 1.
#
# 2.
#
# 3.
#
# Всегда, оформляя проект, держи в голове, что тебе придется возвращаться к работе над ним спустя какое-то время. Если он будет структурировано оформлен, ты будешь тратить гораздо меньше времени на то, чтобы снова вникнуть в него
# </div>

# %%
df['balcony'] = df['balcony'].fillna(0)
df['ponds_around3000'] = df['ponds_around3000'].fillna(0)
df['parks_around3000'] = df['parks_around3000'].fillna(0)
df['rooms'].loc[df['rooms'] == 0] = 1
df['days_exposition'] = df['days_exposition'].fillna(df['days_exposition'].mean())

# Проверка
print(df['balcony'].isna().sum())
print(df['ponds_around3000'].isna().sum())
print(df['parks_around3000'].isna().sum())
print(df['rooms'].unique())
print(df['days_exposition'].isna().sum())
# Out:
# 0
# 0
# 0
# [ 3  1  2  4  5  6  7 11  8 14 10 15  9 19 16 12]
# 0
# /Users/mike/opt/anaconda3/envs/praktikum/lib/python3.7/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %% [markdown]
# <blockquote> О чем он меня предупреждает здесь? Я так и не разобрался. Как избавиться от предупреждения? </blockquote>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# pd.options.mode.chained_assignment = None  # default='warn' - отключить предупреждение
#
# Предупреждает, что панды выполняют операции с копией, по ссылке описано почему возникает предупреждение
#
# https://stackoverflow.com/questions/20625582/how-to-deal-with-settingwithcopywarning-in-pandas
# </div>

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      0.0  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# Замена типов данных

# %%
# Точности до рубля дотаточно
df['last_price'] = df['last_price'].astype(int)
# Так с датами будет удобнее работать. Оставлю только дату, поскольку время везде 00:00:00
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
# Дробные этажи - экзотика, но NaNы не могут быть целого типа
# df['floors_total'] = df['floors_total'].astype(int)

# Без балконов "девять и три четверти"
df['balcony'] = df['balcony'].astype(int)

# В соответствии с описанием данных
df['parks_around3000'] = df['parks_around3000'].astype(int)
df['ponds_around3000'] = df['ponds_around3000'].astype(int)

# NaNы не могут быть целого типа
# df['days_exposition'] = df['days_exposition'].astype(int)

# %%
# Проверка
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null int64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null datetime64[ns]
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 23699 non-null int64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        23699 non-null int64
# ...

# %% [markdown]
# Колонка `is_apartment` содержит много пропусков, ее не стоит переводить в булев тип. Иначе NaN превратится в True.

# %% [markdown]
# ### Вывод

# %% [markdown]
# - Пропущенные значения отсутствуют менее чем в половине колонок. Больше всего пропущенных значений в колонке `is_apartment`. Разумных предположений о природе пропусков здесь у меня нет. Оставлю их как есть. _Скорее всего в пропущенных значениях долно быть записано False - вряд ли Яндекс.Недвижимость специализируется на апартаментах._
#
# - Пропуски в колонке `balcony` могли появиться, потому что пользователи не хотят в явном виде сообщать об отсутствии балкона. Пропуски заполнены на нули. Аналогично с `parks_nearest`, `ponds_nearest`.
#
# - Данные в колонках `airports_nearest`, `cityCenters_nearest`, `parks_nearest`, `ponds_nearest` были получено автоматически и пропуски здесь, скорее всего, технического характера.
#
# - Возможно, расстояние до центра `cityCenters_nearest` не указано в небольших населенных пунктах (там, где это расстояние не играет существенной роли). Можно было бы заменить пропуски здесь на средние значения для каждого населенного пункта, но в датасете достаточно много населенных пунктов, для всех квартир в которых расстояние не указано.
#
# - У всех квартир, для которых не указаны `days_exposition`, есть `last_price`. В описании данных сказано, что `last_price` - цена на момент снятия с публикации. Разумно предположить, что все объявления в датасете были сняты с публикации в какой-то момент. Заполнил пропуски в `days_exposition` медианным значением по этой колонке.
#
# - Пропусков в `kitchen_area`, `living_area`, `floors_total`, `locality_name` относительно немного и на результаты анализа они не должны повлиять. Оставлю их.
#
# - Заменены типы данных в некоторых колонках.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий от ревьюера v_1
# Критично
#
# В датасете пропусков гораздо больше. Заполнять их не необязательно, но комментарий дать необходимо по каждому столбцу в котором пропуск. Предположить природу пропуска и объяснить свои действия с ними
# </div>

# %% [markdown]
# ### Ответ от студента v_1
# <blockquote>
#     Предположил и объяснил
# </blockquote>

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %%
# Цена квадратного метра
df['sqr_meter_price'] = (df['last_price'] / df['total_area']).astype(int)

df['sqr_meter_price']
# Out:
# 0        120370
# 1         82920
# 2         92785
# 3        408176
# 4        100000
#           ...
# 23694     72490
# 23695     52542
# 23696     44091
# 23697    149511
# 23698     41795
# Name: sqr_meter_price, Length: 23699, dtype: int64

# %%
# День, месяц и год публикации в отдельных колонках

df['exposition_day'] = df['first_day_exposition'].dt.day
df['exposition_month'] = df['first_day_exposition'].dt.month
df['exposition_year'] = df['first_day_exposition'].dt.year
df['exposition_weekday'] = df['first_day_exposition'].dt.weekday

exposition_test = ['first_day_exposition', 'exposition_day',
                   'exposition_month', 'exposition_year', 'exposition_weekday']

df[exposition_test].head()
# Out:
#   first_day_exposition  exposition_day  exposition_month  exposition_year  \
# 0           2019-03-07               7                 3             2019
# 1           2018-12-04               4                12             2018
# 2           2015-08-20              20                 8             2015
# 3           2015-07-24              24                 7             2015
# 4           2018-06-19              19                 6             2018
#
#    exposition_weekday
# 0                   3
# 1                   1
# 2                   3
# 3                   4
# 4                   1

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий от ревьюера v_1
# Критично
#
# Нужен день недели
# </div>

# %% [markdown]
# ### Ответ от студента v_1
#
# <blockquote> Добавил </blockquote>

# %%
def floor_category(row):
    """
    Категоризация квартир по номеру этажа:
    варианты — первый, последний, другой

    Args:
        row (pd.Series): Строка датафрейма

    Returns:
        [str]: 'первый', 'последний', 'другой'
    """    

    floor = row['floor']
    floors_total = row['floors_total']

    if floor == 1:
        return 'первый'
    
    elif floor == floors_total:
        return 'последний'

    else:
        return 'другой'

# %%
df['floor_category'] = df.apply(floor_category, axis=1)

# Проверка
df['floor_category'].value_counts()
# Out:
# другой       17446
# последний     3336
# первый        2917
# Name: floor_category, dtype: int64

# %% [markdown]
# Неопределенных случаев нет, это хорошо

# %%
df['living2total_ratio'] = df['living_area'] / df['total_area']
df['kitchen2total_ratio'] = df['kitchen_area'] / df['total_area']

# Проверка
df.plot(y=['living2total_ratio', 'kitchen2total_ratio'],
        kind='hist', bins=np.linspace(0, 1, 30), alpha=.7)

plt.xlabel('ratio')

plt.show()

# %% [markdown]
# Забавно, что есть квартиры, кухня в некоторых квартирах занимает более половины общей площади. Немаленькие в том числе:

# %%
df[df['kitchen2total_ratio'] > 0.5].plot(y='total_area', kind='hist')

plt.title('kitchen2total_ratio > 0.5')
plt.xlabel('total_area')

plt.show()

# %% [markdown]
# Квартиры с долей жилой площади меньше половины от общей тоже заслуживают внимания:

# %%
small_living2total_ratio = df[df['living2total_ratio'] < 0.5].shape[0] / df.shape[0]

print(f'Всего таких квартир: {small_living2total_ratio:.1%}')
# Out:
# Всего таких квартир: 23.7%

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Отличные проверки 👍🏻
#
# </div>

# %% [markdown]
# ### Вывод

# %% [markdown]
# - Созданы новые вспомогательные колонки, произведена категоризация по этажам

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
#
# Отлично, все расчеты верны 👍🏻
# </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
# Рекомендация
#
# Надо обозначать шаги исследования)
# </div>

# %%
df.plot(kind='hist', y='total_area', logy=True)

plt.xlabel('total_area')

plt.show()

# %%
df['total_area'].quantile([.5, .92, .95])
# Out:
# 0.50     52.0
# 0.92    100.0
# 0.95    116.0
# Name: total_area, dtype: float64

# %% [markdown]
# 92% квартир в выборке имеют площадь менее 100 кв. метров.

# %%
df.plot(kind='scatter', x='total_area', y='living_area', alpha=.2)

plt.plot([0, 800], [0, 400], color='red', label='living_area = total_area / 2')

plt.legend()

plt.show()

# %% [markdown]
# Квартиры стремятся не попадать ниже красной прямой. Оно и понятно.

# %%
df.plot(kind='hist', y='last_price', bins=150, xlim=(10**5, .3e9))

plt.vlines(1.7e8, 0, 300)

plt.yscale('log')
plt.xlabel('last_price')
plt.show()

# %% [markdown]
# - Квартиры стоимостью выше 170 млн. определю как выбросы и исключу из датасета:

# %%
df = df[df['last_price'] < 1.7e8]

# Проверка
df['last_price'].max()
# Out:
# 160000000

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Чтобы избавиться от e-значений используй такую запись:
#
# pd.options.display.float_format = '{:,.1f}'.format
#
# 1 - число разрядов после запятой
#
# </div>

# %% [markdown]
# Дешевых квартир больше всего, с ростом цены количество квартир уменьшается.

# %%
# Почему то зависает такая формулировка:
# df.plot(y='rooms', kind='bar')

df['rooms'].value_counts().plot.bar()

plt.xlabel('Количество комнат')
plt.yscale('log')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# df.plot(y='rooms', kind='bar') - конечно же зависнет, барплот работает с агрегированными данными))
#
#
# </div>

# %% [markdown]
# - Больше всешго однушек, двушек и трешек. С увеличением числа комнат количество квартир уменьшается.
#
# - Квартир с количеством комнат больше 10 исчещающе мало, их можно исключить из рассмотрения:

# %%
df = df[~(df['rooms'] > 10)]

# %%
df.plot(kind='scatter', x='total_area', y='ceiling_height')

plt.vlines(510, 0, 80)

plt.show()

# %% [markdown]
# - Наверху явный выброс, похоже на опечатку. Видимо, пользователь ввел `100` вместо `10`. Остальные колонки выглядат адекватно, исправлю это значение.
#
# - Также определю как выбросы и исключу квартиры с `total_area` больше 510

# %%
df.loc[df['ceiling_height'] == 100] = 10

df = df[df['total_area'] < 510]

# %%
df.plot(kind='scatter', x='total_area', y='ceiling_height')

plt.vlines(510, 0, 30)

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10), sharex=True)



# Проверка
df.plot(kind='scatter', x='ceiling_height', y='total_area', alpha=.3, ax=ax1)

df.plot(y='ceiling_height', kind='hist', ax=ax2)

ax2.set_xlabel('Высота потолка')
ax2.set_yscale('log')


plt.show()

# %% [markdown]
# Интересная группа с высотой потолка более 20 метров. Более 18% таких квартир - апартаменты:

# %%
high_ceiling_apart_ratio = df[df['ceiling_height'] > 20]['is_apartment'].mean()

print(f'Доля апартаментов среди квартир с нетипично высокими потолками: {high_ceiling_apart_ratio:.1%}')

print(f'Доля апартаментов среди всех, описанных (не пропущенных) в выборке: {init_df["is_apartment"].mean():.1%}')
# Out:
# Доля апартаментов среди квартир с нетипично высокими потолками: 18.2%
# Доля апартаментов среди всех, описанных (не пропущенных) в выборке: 1.8%

# %% [markdown]
# - Будет разумно исключить эти квартиры из датасета за нехарактерно высокие потолки:

# %%
df = df[df['ceiling_height'] < 20]

# %% [markdown]
# Все четыре гистограммы рядом:

# %%
for col in ['total_area', 'last_price', 'rooms', 'ceiling_height']:

    df.plot(kind='hist', y=col, logy=True, title=col, figsize=(10, 4))

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
#
# Шаг выполнен отлично 👍🏻
# </div>

# %% [markdown]
# **Время продажи квартиры**

# %%
df.plot(kind='hist', y='days_exposition', bins=40,
        logy=True, xlim=(-10, 1400), ylim=(8, 8 * 10**3))

quantiles = df['days_exposition'].quantile([.05, .5, .95])
print(quantiles)

plt.vlines(quantiles, 0, 10**4, color='red', label='quantiles [.05, .5, .95]', ls='--')
plt.vlines(df['days_exposition'].mean(), 0, 10**4, label='mean')
plt.xlabel('длительность c публикации до продажи в днях')

plt.legend()

plt.show()
# Out:
# 0.05     10.0
# 0.50    144.0
# 0.95    620.6
# Name: days_exposition, dtype: float64

# %% [markdown]
# - Большой всплеск в районе 200 дней
# - Также наблюдается пики на "красивых" значениях:

# %%
df['days_exposition'].value_counts().nlargest(6)
# Out:
# 180.888634    2444
# 45.000000      396
# 60.000000      274
# 7.000000       154
# 30.000000      150
# 90.000000      104
# Name: days_exposition, dtype: int64

# %% [markdown]
# Ниже можно увидеть их:

# %%
df.plot(kind='scatter', x='days_exposition', y='last_price',
        logy=True, logx=True, alpha=.1,
        xlim=(.8, 2 * 10**3), ylim=(1e5, 1e9))

plt.show()

# %%
# Избавляюсь от выбивающихся значений
df = df[df['days_exposition'] > 2]

# Выкину мусорную строку, заполненную десятками
df = df[df['exposition_year'] > 2010]

# %% [markdown]
# - Обычно продажа занимает около 95 дней
# - Менее 5% квартир оказываются проданы за 9 дней и меньше: это подозрительно быстро
# - Менее 5% квартир оказываются проданы за 647 дней и больше: это подозрительно долго
# - Медиана меньше среднего, что указывает на наличие выбросов на малых значениях
# - Выбросы по времени продажи, площади, цене, числу комнат, высоте потолков были исключены
# - На графике видны особенности: заметное количество относительно дешевых квартир оказываются проданы через 45 дней с момента публикации, заметное количество отностильено дорогих квартир оказваются проданы через 90 дней

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий от ревьюера v_1
# Критично
#
# Чистка выбивающихся значений относилась и к площада, цене, числу комнат и высоте потолков
#
# Если не чистишь, то нужно прокомментировать, почему решаешь оставить
# </div>

# %% [markdown]
# ### Ответ от студента v_1
# <blockquote>
#     Почистил
# </blockquote>

# %% [markdown]
# #### Какие факторы больше всего влияют на стоимость квартиры?

# %%
df.plot(kind='scatter', x='total_area', y='last_price',
        alpha=.05, logy=True, logx=True, xlim=(10, 1000),
        ylim=(10 ** 5, 10 ** 9))

plt.show()

# %% [markdown]
# - Брюхо распределения сидит от 1 до 11 млн. рублей и от 20 до 100 кв. метров.

# %%
price_area_corr_coef = df['last_price'].corr(df['total_area'])
price_rooms_corr_coef = df['last_price'].corr(df['rooms'])

print(f'Коэффициент корреляции между ценой и площадью квартиры: {price_area_corr_coef:.0%}')
print(f'Коэффициент корреляции между ценой и количеством комнат: {price_rooms_corr_coef:.0%}')
# Out:
# Коэффициент корреляции между ценой и площадью квартиры: 75%
# Коэффициент корреляции между ценой и количеством комнат: 45%

# %% [markdown]
# - Заметная корреляция наблюдается между ценой и площадью квартиры и между ценой и количеством комнат

# %%
target_data = df[['last_price', 'total_area', 'cityCenters_nearest', 'rooms']]

target_data.corr()
# Out:
#                      last_price  total_area  cityCenters_nearest     rooms
# last_price             1.000000    0.751473            -0.274728  0.446362
# total_area             0.751473    1.000000            -0.244866  0.765381
# cityCenters_nearest   -0.274728   -0.244866             1.000000 -0.190805
# rooms                  0.446362    0.765381            -0.190805  1.000000

# %%
pd.plotting.scatter_matrix(target_data, figsize=(12,12))

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий от ревьюера v_1
# Критично
#
# 1. Нет анализа по числу комнат
#
# 2. Нет никаких комментариев, кроме выведенного коэффициента корреляции
# </div>

# %% [markdown]
# ### Ответ от студента v_1
# <blockquote>
#     Исправил
# </blockquote>

# %%
fig, axs = plt.subplots(1, 3, figsize=(10, 7), sharey=True)

for floor, ax in zip(['первый', 'последний', 'другой'], axs):

    (df[df['floor_category'] == floor]['last_price']
        .plot(kind='box', ax=ax, logy=True, title=floor))

# %% [markdown]
# - Тип этажа (`первый`, `последний` или `другой`) не оказывает заметного влияния на медианную стоимость квартиры. Тем не менее, распределение стоимости квартир на последнем этаже имеет гораздо больший разброс.
# - Без дополнительного анализа кажется, что наибольший вклад в формирование стоимости вносит площадь квартиры (коэффициент корреляции 75%) и количестов комнат (45%). Остальные параметры скоррелированы незначительно.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий от ревьюера v_1
# Критично
#
# Боксплот отличная визуализация, но где-же другой этаж?)
# </div>

# %% [markdown]
# ### Ответ от студента v_1
#
# На категорию "другой" не смотрел, потому что в чек-листе такая формулировка:
#
# <blockquote> Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра </blockquote>
#
# Теперь добавил, вывод остается прежним.

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 7), sharey=True)

for col, ax in zip(['exposition_weekday', 'exposition_month', 'exposition_year'], axs):

    df.plot(kind='scatter', y='last_price', x=col, ax=ax, alpha=.4, logy=True, ylim=(1e5, 1e9))
    
    if col == 'exposition_weekday':
        ax.set_xlim(-1, 7)
    
ax.set_xlim(2013, 2020)

fig, axs = plt.subplots(1, 3, figsize=(20, 5), sharey=True)

for col, ax in zip(['exposition_weekday', 'exposition_month', 'exposition_year'], axs):

    df.groupby(col)['last_price'].count().plot(ax=ax)
    
    if col == 'exposition_weekday':
        ax.set_xlim(-1, 7)
    
ax.set_xlim(2013, 2020)

fig.suptitle('количество объявлений')

plt.show()

# %% [markdown]
# - Кажется, что стоимость квартиры не зависит от дня и месяца размещения объявления.
#
# - Самый большой разброс по стоимости квартир наблюдался на Яндекс.Недвижемости в 2017 году. На 2019 год можно не смотреть, потому что данные по нему есть только до мая.

# %%
(df.groupby('exposition_weekday')['last_price']
             .mean().plot.bar(ylim=(0, 8e6)))

plt.ylabel('last_price')

plt.show()

# %%
(df.groupby('exposition_month')['last_price']
             .mean().plot.bar())

plt.ylabel('last_price')

plt.show()

# %%
fig, ax = plt.subplots()

df.groupby('exposition_year')['last_price'].mean().plot.bar(ax=ax, label='mean')
df.groupby('exposition_year')['last_price'].median().plot.bar(ax=ax, edgecolor='red',
                                                              label='median',
                                                              color='none',
                                                              lw=3)
ax.set_ylabel('last_price')

ax.legend()

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий от ревьюера v_1
# Критично
#
# График по годам вообще не читается
#
# Вообще рекомендую в этой части сделать барплоты по средним значениям или боксплоты, как ты для категории этажа делал. Для дня недели, месяца, года, получится очень наглядно
# </div>

# %% [markdown]
# ### Ответ от студента v_1
# <blockquote>
#    Подправил график по годам, добавил представление чере барплот. Оказалось, что в 2014 средняя и медианная была выше, чем в последующие года
# </blockquote>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Молодец, что не пытаешься найти зависимости через корреляцию там, где она не уместа
#
# </div>

# %%
df['last_price'].nsmallest(3)
# Out:
# 8793      12190
# 16219    450000
# 10782    490000
# Name: last_price, dtype: int64

# %% [markdown]
# Выкину квартиру за 12 тыс. рублей:

# %%
df = df.loc[df['last_price'] != 12190]

df['last_price'].nsmallest(3)
# Out:
# 16219    450000
# 10782    490000
# 4405     500000
# Name: last_price, dtype: int64

# %%
# 10 населённых пунктов с наибольшим числом объявлений
locality_stat_10 = df.groupby('locality_name')['last_price'].count().nlargest(10)

locality_stat_10_names = locality_stat_10.index

locality_stat_10_names
# Out:
# Index(['Санкт-Петербург', 'Всеволожск', 'Пушкин', 'посёлок Шушары', 'Колпино',
#        'посёлок Мурино', 'Гатчина', 'Петергоф', 'посёлок Парголово',
#        'Сестрорецк'],
#       dtype='object', name='locality_name')

# %%
# Соответствующий датафрейм
locality_stat_df = df.query('locality_name in @locality_stat_10_names')

# Проверка
locality_stat_df['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'Петергоф', 'посёлок Парголово', 'Пушкин',
#        'посёлок Мурино', 'Гатчина', 'Колпино', 'Всеволожск', 'Сестрорецк',
#        'посёлок Шушары'], dtype=object)

# %%
locality_stat_10.sort_values(ascending=False).plot.bar(figsize=(10, 5), logy=True)

plt.ylabel('количество объявлений')

plt.show()

# %%
locality_stat_prise_10 = locality_stat_df.groupby('locality_name')['last_price'].mean()

locality_stat_prise_10.sort_values(ascending=False).plot.bar(figsize=(10, 5), logy=True)

plt.ylabel('средняя стоимость квартиры')

plt.show()

# %% [markdown]
# - В среднем самые дорогие квартиры в Питере, самые дешевые - в Выборге

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Расчеты верны, молодец, что добавил визуализаций
#
# </div>

# %% [markdown]
# ### Квартиры в центре

# %%
spb_df = df.query('locality_name == "Санкт-Петербург"')

# %%
spb_df['cityCenters_nearest'].isna().sum()
# Out:
# 31

# %% [markdown]
# Прежде всего избавлюсь от строк с пропусками в колонке `cityCenters_nearest`:

# %%
spb_df = spb_df[~spb_df['cityCenters_nearest'].isna()].reset_index()

# Проверка
spb_df['cityCenters_nearest'].isna().sum()
# Out:
# 0

# %%
# print(f'Всего потеряно {1 - spb_df.shape[0] / df.shape[0]:.0%} данных')

# %%
spb_df['cityCenters_nearest_km'] = (spb_df['cityCenters_nearest'] / 1000).round(0).astype(int)

# print(spb_df['cityCenters_nearest_km'].isna().sum())

spb_df = spb_df.sort_values(by='cityCenters_nearest_km')

spb_df
# Out:
#       index  total_images  last_price  total_area first_day_exposition  rooms  \
# 8897  20873            18    11500000       113.5  2018-09-17 00:00:00      3
# 5854  13776             5    30600000       162.0  2018-07-09 00:00:00      7
# 3676   8677            15    13500000        98.0  2017-12-19 00:00:00      3
# 5825  13694             2    31099000       159.0  2018-06-25 00:00:00      5
# 947    2291             6    27000000       173.6  2015-06-11 00:00:00      5
# ...     ...           ...         ...         ...                  ...    ...
# 5151  12160             8     2450000        43.0  2018-08-14 00:00:00      1
# 4939  11652            16     4700000        51.0  2016-06-07 00:00:00      2
# 8483  19892            20     4370000        54.7  2016-03-23 00:00:00      3
# 5527  13031            16     4200000        56.8  2018-07-04 00:00:00      2
# 7141  16787            20     4850000        85.8  2019-04-22 00:00:00      3
#
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
# Рекомендация
#
# Обрати внимание на то, как ты округляешь. 4.9 у тебя округлятся до 4
#
# </div>

# %% [markdown]
# ### Ответ от студента v_1
# <blockquote> Исправил, усвоил </blockquote>

# %%
mean_prise_meter = spb_df.groupby('cityCenters_nearest_km')['last_price'].mean()

mean_prise_meter.plot(ylim=(0, 2.5e7), figsize=(10, 10))

plt.vlines(9, 0, 3e7, color='red', ls='--')

plt.show()

# %% [markdown]
# - После 9 километров от центра города цена перестает резко падать, обозначу этот радиус центром города

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Центральная граница определена верно 👍🏻
#
# </div>

# %%
spb_center_df = spb_df.query('cityCenters_nearest_km <= 9')

spb_center_df
# Out:
#       index  total_images  last_price  total_area first_day_exposition  rooms  \
# 8897  20873            18    11500000       113.5  2018-09-17 00:00:00      3
# 5854  13776             5    30600000       162.0  2018-07-09 00:00:00      7
# 3676   8677            15    13500000        98.0  2017-12-19 00:00:00      3
# 5825  13694             2    31099000       159.0  2018-06-25 00:00:00      5
# 947    2291             6    27000000       173.6  2015-06-11 00:00:00      5
# ...     ...           ...         ...         ...                  ...    ...
# 4385  10299            14     7800000        92.2  2017-09-21 00:00:00      4
# 7500  17562             1     3900000        59.0  2016-03-13 00:00:00      3
# 6686  15723            19     5550000        54.9  2019-04-27 00:00:00      2
# 499    1225            11     3000000        28.0  2017-10-03 00:00:00      1
# 4372  10269             3     4835000        38.0  2017-11-13 00:00:00      1
#
# ...

# %%
for col in ['total_area', 'last_price', 'rooms', 'ceiling_height']:

    fig, ax = plt.subplots()

    spb_df.plot(kind='hist', y=col, logy=True, title=col,
                figsize=(10, 4), bins=30, ax=ax, label='весь СПб')

    spb_center_df.plot(kind='hist', histtype='step', y=col, logy=True, label='центр',
                       title=col, figsize=(10, 4), bins=30, ax=ax, color='red', lw=2)

# %% [markdown]
# - Не похоже, чтобы формы распределений для всех данных и для центра города заметно различались

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Крутые визуализации 👍🏻
#
# </div>

# %%
for stat_df, title in zip([spb_df, spb_center_df], ['весь СПб', 'центр']):

    print(f'f****** {title} ******')

    target_data = stat_df[['last_price', 'total_area', 'cityCenters_nearest', 'rooms']]
    print(target_data.corr())

    pd.plotting.scatter_matrix(target_data, figsize=(12,12))

    plt.show()
# Out:
# f****** весь СПб ******
#                      last_price  total_area  cityCenters_nearest     rooms
# last_price             1.000000    0.754612            -0.348270  0.457789
# total_area             0.754612    1.000000            -0.356968  0.766418
# cityCenters_nearest   -0.348270   -0.356968             1.000000 -0.300815
# rooms                  0.457789    0.766418            -0.300815  1.000000
# f****** центр ******
#                      last_price  total_area  cityCenters_nearest     rooms
# last_price             1.000000    0.727821            -0.157880  0.417438
# total_area             0.727821    1.000000            -0.228216  0.756887
# cityCenters_nearest   -0.157880   -0.228216             1.000000 -0.267410
# rooms                  0.417438    0.756887            -0.267410  1.000000

# %% [markdown]
# - Аналогично для корреляционных матриц

# %%
# fig, axs = plt.subplots(1, 3, figsize=(10, 7), sharey=True)

# for floor, ax in zip(['первый', 'последний', 'другой'], axs):


for stat_df, title in zip([spb_df, spb_center_df], ['весь СПб', 'центр']):

    fig, axs = plt.subplots(1, 3, figsize=(10, 7), sharey=True)

    fig.suptitle(title)

    for floor, ax in zip(['первый', 'последний', 'другой'], axs):

        (stat_df[stat_df['floor_category'] == floor]['last_price']
                 .plot(kind='box', ax=ax, logy=True, title=floor))

# %% [markdown]
# - На все категории этажей медианная цена на квартиры в центре выше, чем во всем городе

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий от ревьюера v_1
# Критично
#
# Тут тоже надо другой этаж добавить
#
# </div>

# %% [markdown]
# ### Ответ от студента v_1
# <blockquote> Добавил </blockquote>

# %% [markdown]
# ### Вывод

# %% [markdown]
# - Созданы новые вспомогательные колонки, произведена категоризация по этажам
# - Определен основной фактор, влияющий на стоимость квартир
# - Для квартир в центре Санкт-Петербурга произведено дополнительное исследование

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В проекте были исследованы данные сервиса Яндекс.Недвижимость. Данные содержали пропуски, которые были обработаны перед анализом.
#
# Получены следующие выводы:
#
# - Стоимость квартиры не зависит от дня и месяца размещения объявления.
# - C 2014 по 2016 год наблюдается тренд на снижение средней и медианной цены за квартиры. Далее цена остается примерно одинаковой.
# - Тип этажа (`первый`, `последний` или `другой`) не оказывает заметного влияния на медианную стоимость квартиры. Тем не менее, распределение стоимости квартир на последнем этаже имеет гораздо больший разброс.
# - Наибольший вклад в формирование стоимости вносит площадь квартиры (коэффициент корреляции 75%) и количестов комнат (45%). Остальные параметры скоррелированы незначительно.
#
# Отдельно для Петербурга:
#
# - В среднем самые дорогие квартиры в Санкт-Петербурге, самые дешевые - в Выборге.
# - Центральная область может быть ограничена 9 километрами.
# - Распределения параметров для центра города схожи для аналогичными распределениями для всего города.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Общий вывод 👍🏻
#
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод info())
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?"
# - [x]  выполнено задание: "Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили."
# - [x]  выполнено задание: "Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года. "Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце '*locality_name'*. "
# - [x]  выполнено задание: "Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (*'locality_name'*). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона. "
# - [x]  выполнено задание: "Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?"
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
